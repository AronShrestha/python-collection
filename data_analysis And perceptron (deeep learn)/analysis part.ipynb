# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.DataFrame(np.random.randn(10,4),index = pd.date_range('2021-07-18',periods=10))
# Out:
#                    0         1         2         3
# 2021-07-18  1.676502 -1.341478 -0.255261  0.450361
# 2021-07-19  0.934656  0.560415 -0.718202 -0.641643
# 2021-07-20 -0.147372 -0.962864 -1.049986 -0.291137
# 2021-07-21 -1.994389  0.697098  0.793131 -0.681722
# 2021-07-22 -0.494445 -0.479233 -0.861029 -0.431565
# 2021-07-23  1.632890  0.663750  1.626821  0.727258
# 2021-07-24 -0.631494 -0.430841 -0.451148  1.697803
# 2021-07-25  0.361411  0.334188  0.145577  0.328702
# 2021-07-26  1.246428  1.353989  0.983204 -2.634043
# 2021-07-27 -0.477344 -2.230987  1.227048 -1.145165

# %%
df = pd.DataFrame(np.random.randn(10,4),index = pd.date_range('2021-07-18',periods=10),columns=['a','b','c','d'])

# %%
a =  np.random.randn(10,2)
a
# Out:
# array([[ 1.46727713, -0.86263198],
#        [-0.96320906,  1.92067076],
#        [ 1.39859281, -1.65245293],
#        [-0.28571385, -0.35343927],
#        [-0.56307391,  0.60742185],
#        [ 2.10999658,  0.32562468],
#        [-0.5771714 ,  0.00305741],
#        [-0.07846276, -0.13012643],
#        [-1.64553432,  0.41822501],
#        [ 0.50606145, -0.39088026]])

# %%
a =  np.random.randn(5,3)
a
# Out:
# array([[-0.13766283,  0.30283625, -0.27925953],
#        [-0.52308436,  0.17153528,  0.2975889 ],
#        [-1.30266603,  1.32590545, -2.48078406],
#        [ 1.01082592,  0.70725828, -0.42803817],
#        [-0.91411157, -0.2662603 ,  1.18812774]])

# %%
index = pd.date_range('2021-07-18',periods=10)
index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    a         b         c         d
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912
# 2021-07-25  0.411749  0.255652  0.317638  1.568017
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941

# %%
df['new']  = df['c'] + df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976

# %%
df['sq_of_d'] = df['d'].apply( lambda x : x**2)

# %%
df
# Out:
#                    a         b         c         d       new   sq_of_d
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819

# %%
df['log_of_d'] =df['d'].apply(lambda x: np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new   sq_of_d  \
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819
#
#             log_of_d
# 2021-07-18       NaN
# 2021-07-19       NaN
# 2021-07-20       NaN
# 2021-07-21 -2.389941
# 2021-07-22  0.292143
# 2021-07-23  0.431022
# 2021-07-24       NaN
# ...

# %%
def test(x):
    if x < 0:
        return x
    else:
        return np.log(x)

# %%
df['new_log_of_d'] = df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new   sq_of_d  \
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819
#
#             log_of_d  new_log_of_d
# 2021-07-18       NaN     -1.132057
# 2021-07-19       NaN     -0.992598
# 2021-07-20       NaN     -1.003841
# 2021-07-21 -2.389941     -2.389941
# ...

# %%
def pos(x):
    if x <0 :
        return 0
    else:
        return 1

# %%
df['new_boolan_of_d'] = df['d'].apply(pos)

# %%
df
# Out:
#                    a         b         c         d       new   sq_of_d  \
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819
#
#             log_of_d  new_log_of_d  new_boolan_of_d
# 2021-07-18       NaN     -1.132057                0
# 2021-07-19       NaN     -0.992598                0
# ...

# %%
df.iloc[0][1]
# Out:
# 1.3333491278772627

# %%
df.loc['2021-07-23','a']
# Out:
# -1.3365491992648408

# %%
df.sort_values(by='d')
# Out:
#                    a         b         c         d       new   sq_of_d  \
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
#
#             log_of_d  new_log_of_d  new_boolan_of_d
# 2021-07-18       NaN     -1.132057                0
# 2021-07-20       NaN     -1.003841                0
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
#making index as column
df['new_date'] = df.index

# %%
df
# Out:
#                    a         b         c         d       new   sq_of_d  \
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819
#
#             log_of_d  new_log_of_d  new_boolan_of_d   new_date
# 2021-07-18       NaN     -1.132057                0 2021-07-18
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df.dtypes
# Out:
# a                         float64
# b                         float64
# c                         float64
# d                         float64
# new                       float64
# sq_of_d                   float64
# log_of_d                  float64
# new_log_of_d              float64
# new_boolan_of_d             int64
# new_date           datetime64[ns]
# dtype: object

# %%
df['year'] =df.index.year
df['month'] =  df.index.month
df['day'] = df.index.day
df['day'] = df.index.day_name()
df
# Out:
#                    a         b         c         d       new   sq_of_d  \
# 2021-07-18 -0.273419  1.333349  0.566663 -1.132057 -0.565394  1.281553
# 2021-07-19  1.151602 -0.207288 -0.118166 -0.992598 -1.110764  0.985250
# 2021-07-20 -0.536738 -0.261297  1.539525 -1.003841  0.535684  1.007696
# 2021-07-21  1.955980  0.107807 -0.089933  0.091635  0.001702  0.008397
# 2021-07-22  0.776446 -0.965236  2.499680  1.339295  3.838975  1.793711
# 2021-07-23 -1.336549 -0.214210 -1.184994  1.538829  0.353835  2.367995
# 2021-07-24  1.127840  0.799507  1.493508 -0.740912  0.752596  0.548951
# 2021-07-25  0.411749  0.255652  0.317638  1.568017  1.885656  2.458679
# 2021-07-26 -0.640645  0.894670  0.534088 -0.018887  0.515202  0.000357
# 2021-07-27 -0.449948 -1.375586  2.055917 -0.315941  1.739976  0.099819
#
#             log_of_d  new_log_of_d  new_boolan_of_d   new_date  year  month  \
# 2021-07-18       NaN     -1.132057                0 2021-07-18  2021      7
# ...

# %%
 df.groupby(by='day').count()
# Out:
#            a  b  c  d  new  sq_of_d  log_of_d  new_log_of_d  new_boolan_of_d  \
# day
# Friday     1  1  1  1    1        1         1             1                1
# Monday     2  2  2  2    2        2         0             2                2
# Saturday   1  1  1  1    1        1         0             1                1
# Sunday     2  2  2  2    2        2         1             2                2
# Thursday   1  1  1  1    1        1         1             1                1
# Tuesday    2  2  2  2    2        2         0             2                2
# Wednesday  1  1  1  1    1        1         1             1                1
#
#            new_date  year  month
# day
# Friday            1     1      1
# Monday            2     2      2
# Saturday          1     1      1
# Sunday            2     2      2
# Thursday          1     1      1
# Tuesday           2     2      2
# Wednesday         1     1      1

# %%
df = pd.DataFrame(np.random.randn(1000,1),index=pd.date_range('2021-07-18',periods =1000),columns=['data'])

# %%
df
# Out:
#                 data
# 2021-07-18 -1.074156
# 2021-07-19  0.264078
# 2021-07-20 -1.423467
# 2021-07-21 -1.381844
# 2021-07-22  1.162151
# ...              ...
# 2024-04-08  0.152731
# 2024-04-09  0.060878
# 2024-04-10 -0.947977
# 2024-04-11  0.928960
# 2024-04-12  1.837945
#
# [1000 rows x 1 columns]

# %%
df['data']>0
# Out:
# 2021-07-18    False
# 2021-07-19     True
# 2021-07-20    False
# 2021-07-21    False
# 2021-07-22     True
#               ...
# 2024-04-08     True
# 2024-04-09     True
# 2024-04-10    False
# 2024-04-11     True
# 2024-04-12     True
# Freq: D, Name: data, Length: 1000, dtype: bool

# %%
df.head()
# Out:
#                 data
# 2021-07-18 -1.074156
# 2021-07-19  0.264078
# 2021-07-20 -1.423467
# 2021-07-21 -1.381844
# 2021-07-22  1.162151

# %%
df.describe()
# Out:
#               data
# count  1000.000000
# mean     -0.041073
# std       1.012724
# min      -3.649478
# 25%      -0.718743
# 50%       0.024322
# 75%       0.608889
# max       3.037279

# %%
df.plot(figsize=(15,18))
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum()
# Out:
# 2021-07-18    -1.074156
# 2021-07-19    -0.810077
# 2021-07-20    -2.233544
# 2021-07-21    -3.615388
# 2021-07-22    -2.453238
#                 ...
# 2024-04-08   -42.952898
# 2024-04-09   -42.892020
# 2024-04-10   -43.839997
# 2024-04-11   -42.911037
# 2024-04-12   -41.073093
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df
# Out:
#                 data
# 2021-07-18 -1.074156
# 2021-07-19  0.264078
# 2021-07-20 -1.423467
# 2021-07-21 -1.381844
# 2021-07-22  1.162151
# ...              ...
# 2024-04-08  0.152731
# 2024-04-09  0.060878
# 2024-04-10 -0.947977
# 2024-04-11  0.928960
# 2024-04-12  1.837945
#
# [1000 rows x 1 columns]

# %%
df['data1']  = df.data.cumsum()

# %%
df
# Out:
#                 data      data1
# 2021-07-18 -1.074156  -1.074156
# 2021-07-19  0.264078  -0.810077
# 2021-07-20 -1.423467  -2.233544
# 2021-07-21 -1.381844  -3.615388
# 2021-07-22  1.162151  -2.453238
# ...              ...        ...
# 2024-04-08  0.152731 -42.952898
# 2024-04-09  0.060878 -42.892020
# 2024-04-10 -0.947977 -43.839997
# 2024-04-11  0.928960 -42.911037
# 2024-04-12  1.837945 -41.073093
#
# [1000 rows x 2 columns]

# %%
df['data2'] =df['data1'].apply(lambda a: np.log(a))
df['data3'] =df['data'].apply(lambda a: np.log(a))
df
# Out:
#                 data      data1  data2     data3
# 2021-07-18 -1.074156  -1.074156    NaN       NaN
# 2021-07-19  0.264078  -0.810077    NaN -1.331510
# 2021-07-20 -1.423467  -2.233544    NaN       NaN
# 2021-07-21 -1.381844  -3.615388    NaN       NaN
# 2021-07-22  1.162151  -2.453238    NaN  0.150272
# ...              ...        ...    ...       ...
# 2024-04-08  0.152731 -42.952898    NaN -1.879080
# 2024-04-09  0.060878 -42.892020    NaN -2.798885
# 2024-04-10 -0.947977 -43.839997    NaN       NaN
# 2024-04-11  0.928960 -42.911037    NaN -0.073690
# 2024-04-12  1.837945 -41.073093    NaN  0.608648
#
# [1000 rows x 4 columns]

# %%
df.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df2 =df1

# %%
df2['is verginica']=df2['species'] == 'virginica'

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      is verginica
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# ...

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      is verginica
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# ...

# %%
gf = df1.plot(figsize=(10,10),title='flower')
gf.set_xlabel ('x-axis')
gf.set_ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
df1.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# is verginica     False
# Name: 0, dtype: object

# %%
a =df1.iloc[0][0:4]
a
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
a.plot()
# Out:
# <AxesSubplot:>

# %%
a.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df3 = sns.load_dataset('titanic')

# %%
df3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df3['pclass'].plot(kind ='bar',figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
df4 =pd.DataFrame(np.random.randn(10,4),columns=['a','b','c','d'])

# %%
df4
# Out:
#           a         b         c         d
# 0 -0.121493 -0.035615  0.325420 -0.627644
# 1  0.144281  0.621189  1.559238  1.124924
# 2 -0.819553  1.467683  1.014577  1.071125
# 3  0.739973  0.972856  1.813208 -0.108397
# 4  0.010249  0.595901 -0.134652  0.088243
# 5 -0.458841  0.490820 -1.134592  0.287207
# 6  0.348542  2.085374 -0.283243  0.669916
# 7  0.442567  0.673169 -0.431332  0.056403
# 8 -1.084375  1.837972 -0.007633 -1.567469
# 9 -1.069128 -0.075804  0.639311 -0.382351

# %%
df4.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.186778   0.863355   0.336030   0.061196
# std     0.645741   0.731491   0.925294   0.811473
# min    -1.084375  -0.075804  -1.134592  -1.567469
# 25%    -0.729375   0.517090  -0.246095  -0.313863
# 50%    -0.055622   0.647179   0.158893   0.072323
# 75%     0.297477   1.343977   0.920761   0.574239
# max     0.739973   2.085374   1.813208   1.124924

# %%
df4.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df2['sepal_width'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.hist( stacked = True ,bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind= 'hist' ,stacked = True ,bins=1000 ,figsize =(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind= 'hist' ,stacked = True ,bins=100 ,figsize =(10,10),title='histogram of iris')
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, ylabel='Frequency'>

# %%
df2.plot(kind= 'hist' ,stacked = True ,bins=100 ,figsize =(10,10),title='histogram of iris',orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, xlabel='Frequency'>

# %%
df2.hist(color= 'r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2.plot.scatter(x='sepal_width', y='petal_width', color='r')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df2.plot.scatter(x='sepal_length', y='petal_width', color='y')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2.plot.scatter(x='sepal_length', y='petal_width', c='petal_length')#this type of graph is useful for finding relation of 2 with respect to third i.e dependancy on third
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.5.0'

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.iplot()
# Out:
# <div>                            <div id="7a7ae96b-5717-47a0-b4db-4ee21dd9b6af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df3.iplot(kind='scatter', x='fare' ,y= 'age')
# Out:
# <div>                            <div id="093a145a-87dd-4f46-9901-18c70a7eae4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind='scatter', x='fare' ,y= 'age',mode='markers')
# Out:
# <div>                            <div id="201dd9f4-4222-4248-a585-0cd48591cec4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind='scatter', x='fare' ,y= 'age',mode='markers',xTitle='fare' ,yTitle='age')
# Out:
# <div>                            <div id="fd589098-d8ca-4c3f-8018-16d668b7e6ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#151516', 'font': {'color': '#D9D9D9'}},
#   'paper_bgcolor': '#151516',
#   'plot_bgcolor': '#151516',
#   'yaxis': {'tickfont': {'color': '#C2C2C2'},
#    'gridcolor': '#434343',
#    'titlefont': {'color': '#D9D9D9'},
#    'zerolinecolor': '#666570',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#C2C2C2'},
#    'gridcolor': '#434343',
#    'titlefont': {'color': '#D9D9D9'},
#    'zerolinecolor': '#666570',
#    'showgrid': True},
#   'titlefont': {'color': '#D9D9D9'}},
#  'annotations': {'fontcolor': '#D9D9D9', 'arrowcolor': '#8C8C8C'}}

# %%
cf.set_config_file(theme = 'polar')
df3.iplot(kind='scatter', x='fare' ,y= 'age',mode='markers',xTitle='fare' ,yTitle='age')
# Out:
# <div>                            <div id="3ecafe09-9df0-4cb7-833d-a5e1bee3d83f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.set_config_file(theme = 'solar')
df3.iplot(kind='scatter', x='fare' ,y= 'age',mode='markers',xTitle='fare' ,yTitle='age')
# Out:
# <div>                            <div id="262d6c14-6c62-4429-89bf-72d21eae6109" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
