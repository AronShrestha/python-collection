# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[x for x in range(50)]

# %%
x2 =[x2*5 for x2 in range(50)]

# %%
plt.plot(x,x2)

# %%
a=pd.read_csv('FitBit data.csv')

# %%
x=[]
for i in range(50):
    x.append(a.loc[i]['TotalSteps'])

# %%
x
# Out:
# [11004,
#  17609,
#  12736,
#  13231,
#  12041,
#  10970,
#  12256,
#  12262,
#  11248,
#  10016,
#  14557,
#  14844,
#  11974,
#  10198,
#  12521,
#  12432,
#  10057,
#  10990,
#  224,
#  1810,
#  815,
#  1985,
#  1905,
#  1552,
#  1675,
#  4506,
#  9218,
#  1556,
#  2910,
#  18464,
#  1335,
#  1004,
#  1111,
#  6344,
#  3572,
#  3910,
#  10000,
#  6627,
#  4636,
#  20237,
#  12912,
#  2819,
#  9921,
#  8046,
#  11166,
#  7842,
#  13840,
#  1329,
#  6847,
#  5367]

# %%
y=[]
for i in range(50):
    y.append(a.loc[i]['Calories'])

# %%
y
# Out:
# [1819,
#  2154,
#  1944,
#  1932,
#  1886,
#  1820,
#  1889,
#  1868,
#  1843,
#  1850,
#  2030,
#  2083,
#  1861,
#  1755,
#  1895,
#  1883,
#  1755,
#  1811,
#  50,
#  1373,
#  1264,
#  1350,
#  1342,
#  1300,
#  1313,
#  1498,
#  1541,
#  1327,
#  1452,
#  1574,
#  1308,
#  1276,
#  1278,
#  1409,
#  1370,
#  1555,
#  1469,
#  706,
#  3323,
#  4029,
#  3436,
#  2444,
#  3098,
#  2925,
#  3202,
#  2928,
#  3290,
#  489,
#  1969,
#  1889]

# %%
plt.plot(x,y)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='TotalSteps',y='Calories',data =a)
# Out:
# <AxesSubplot:xlabel='TotalSteps', ylabel='Calories'>

# %%
a.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
a['date']=pd.DatetimeIndex(a['ActivityDate'])
a.dtypes
# Out:
# Id                                   int64
# ActivityDate                        object
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# date                        datetime64[ns]
# month                                int64
# dtype: object

# %%
a['month']=pd.DatetimeIndex(a['ActivityDate']).month

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='date',y='Calories',data =a)
# Out:
# <AxesSubplot:xlabel='date', ylabel='Calories'>

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x='month',y='Calories',data =a)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Calories'>

# %%
a.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
a
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
a['day']=pd.DatetimeIndex(a['ActivityDate']).day

# %%
a
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='day',y='Calories',data=a)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Calories'>

# %%
a['week']=pd.DatetimeIndex(a['ActivityDate']).week
# Out:
# /tmp/ipykernel_24521/1733107092.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   a['week']=pd.DatetimeIndex(a['ActivityDate']).week

# %%
a
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
a['Day_name']=pd.DatetimeIndex(a['ActivityDate']).day_name()

# %%
a
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='Day_name',y='Calories',data=a)
# Out:
# <AxesSubplot:xlabel='Day_name', ylabel='Calories'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='Calories',y='TotalSteps',data=a)
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='TotalSteps'>

# %%
a['calorie_per_step']=a['Calories']/a['TotalSteps']

# %%
a
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='calorie_per_step',y='TotalSteps',data=a)
# Out:
# <AxesSubplot:xlabel='calorie_per_step', ylabel='TotalSteps'>
